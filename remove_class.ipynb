# %%
import pandas as pd

# Read CSV without header
df = pd.read_csv('model/keypoint_classifier/gesture_3/keypoint.csv', header=None)

# Remove rows where first column == 1
df_cleaned = df[df[0] != 1]

# Save back to CSV (without header and index)
df_cleaned.to_csv('model/keypoint_classifier/gesture_3/keypoint.csv', index=False, header=False)
